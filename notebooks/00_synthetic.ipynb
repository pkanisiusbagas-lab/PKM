# %%
# TODO: import pandas

# %%
# TODO: load dataset.csv + info + head

# %%
# TODO: cek kolom q1-q16, tipe, missing, jawaban invalid

# %%
# TODO: balance leaning, distribusi per soal, histogram q10

# %%
# TODO: tulis LANJUT atau REGENERATE + alasan
