# %%
# TODO: import sklearn.ensemble + load kandidat dari 03

# %%
# TODO: ukur diversitas error antar model

# %%
# TODO: hard + soft voting, catat F1

# %%
# TODO: stacking OOF + meta-learner, catat F1

# %%
# TODO: ensemble vs single terbaik
