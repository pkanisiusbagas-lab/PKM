# %%
# TODO: import pandas, matplotlib

# %%
# TODO: load data lolos gate

# %%
# TODO: tetapkan target + analisis distribusi kelas

# %%
# TODO: frekuensi opsi per soal + crosstab vs target

# %%
# TODO: histogram q10, panjang teks, duplikat, missing

# %%
# TODO: asosiasi fitur-target + tulis 3 hipotesis
