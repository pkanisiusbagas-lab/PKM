# %%
# TODO: import sklearn, xgboost, lightgbm + setup CV

# %%
# TODO: train + CV logistic regression + catat F1

# %%
# TODO: train + CV decision tree + catat F1

# %%
# TODO: train + CV random forest + catat F1

# %%
# TODO: train + CV xgboost + catat F1

# %%
# TODO: train + CV lightgbm + catat F1

# %%
# TODO: tabel 5 model + keputusan kandidat ensemble
