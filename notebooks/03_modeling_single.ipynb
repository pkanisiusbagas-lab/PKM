# %% [markdown]
# # 03 - Modeling Single
# TODO: Logistic Regression | Decision Tree | Random Forest | XGBoost | LightGBM

# %%
# TODO: logistic regression

# %%
# TODO: decision tree

# %%
# TODO: random forest

# %%
# TODO: xgboost

# %%
# TODO: lightgbm
