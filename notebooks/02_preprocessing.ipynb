# %%
# TODO: import pandas, sklearn

# %%
# TODO: load data + pisahkan fitur dan target

# %%
# TODO: one-hot kategorikal + scaler q10 + teks opsional

# %%
# TODO: train/val/test + verifikasi proporsi kelas

# %%
# TODO: rakit Pipeline, cek leakage, save preprocessor + split
